# %%
import pandas as pd
import numpy as np
import import_ipynb
from utils import show
import json
# Out:
# importing Jupyter notebook from utils.ipynb

# %%
xlsx = pd.ExcelFile('examples/ex1.xlsx')

# %%
frame = pd.read_excel('examples/ex1.xlsx','Sheet1')

# %%
show(frame)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# --------------------
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
issues = pd.read_json(json.dumps(resp.json()))

# %%
issues[['number','title','labels','state']]
# Out:
#     number                                              title  \
# 0    26133  Unclear error message when dealing with Intege...
# 1    26132  DOC: add deprecated to docstring of Series.dat...
# 2    26131  pd.Timestamp.isoformat does not implement keyw...
# 3    26130                   register_index_accessor Question
# 4    26128  CLN: remove unneeded inheritance from base object
# 5    26127  Inspection of some cython produced functions c...
# 6    26125  BUG: np.min(pd.Index) and np.max(pd.Index) rai...
# 7    26124    to_csv to Google Cloud Storage ignores encoding
# 8    26123  Reindexing a sparse data structure with a diff...
# 9    26122  Unexpected 'to_datetime' behaviour for datetim...
# 10   26121  to_parquet and read_parquet are not symmetric ...
# 11   26119  Modify index of Series derived from Dataframe ...
# 12   26118  Should assert_frame_equal allow for a 'None' d...
# 13   26114  DEPR: deprecate DataFrame.iteritems and Series...
# 14   26113  BUG: Preserve index order when constructing Da...
# 15   26111  to_latex adds extra empty header row when inde...
# 16   26109          Constructing PeriodIndex with string data
# 17   26108  PERF: Performance regression (memory and time)...
# 18   26107  TypeError on while retrieving values from a Se...
# 19   26106  Improve documentation for assert_frame|series_...
# 20   26104  ENH: Add parameter to download BigQuery result...
# 21   26103                               add install for xsel
# 22   26102  Include missing data count in pd.DataFrame.des...
# 23   26101  Improve documentation for assert_frame|series_...
# 24   26100  is_categorical_dtype depends on boolness of th...
# 25   26097  BUG: _convert_and_box_cache raise ValueError: ...
# 26   26096  Dtype attributes (eg PeriodDtype.freq) should ...
# 27   26094                                        day_of_week
# 28   26080  BUG resolving issue 26051 and adding a unit test.
# 29   26077       TST: consolidate set_op tests across indexes
#
#                                                labels state
# 0                                                  []  open
# 1   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 2                                                  []  open
# 3                                                  []  open
# 4   [{'id': 49747336, 'node_id': 'MDU6TGFiZWw0OTc0...  open
# 5                                                  []  open
# 6   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 7                                                  []  open
# 8   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 9   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 10                                                 []  open
# 11  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 12  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 13  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 14  [{'id': 1049312478, 'node_id': 'MDU6TGFiZWwxMD...  open
# 15                                                 []  open
# 16  [{'id': 60635328, 'node_id': 'MDU6TGFiZWw2MDYz...  open
# 17  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 18                                                 []  open
# 19  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 20  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 21  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 22  [{'id': 1049312478, 'node_id': 'MDU6TGFiZWwxMD...  open
# 23  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 24  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 25  [{'id': 211840, 'node_id': 'MDU6TGFiZWwyMTE4ND...  open
# 26  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 27  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 28  [{'id': 42670965, 'node_id': 'MDU6TGFiZWw0MjY3...  open
# 29  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
